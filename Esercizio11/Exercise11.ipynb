# %% [markdown]
# # <span style="color:red"> Numerical Simulation 11 </span>

# %% [markdown]
# ## **Exercise 11.1**

# %% [markdown]
# In this first exercise we try a linear fit with just one neuron and one layer. Increasing the number of epochs and the number of data points is the key to make this fits works. However having a large number of data is more important than ingreasing epoches. Indeed I've checked that with a larger $N_{\mathrm{train}}$ the fits works well even if I increase $\sigma$.

# %%
import numpy as np
import matplotlib.pyplot as plt
# target parameters of f(x) = m*x + b
m = 2 # slope
b = 1 # intersect

# generate training inputs
np.random.seed(0)
x_train = np.random.uniform(-1, 1, 500)
x_valid = np.random.uniform(-1, 1, 50)
x_valid.sort()
y_target = m * x_valid + b # ideal (target) linear function

sigma = 0.4 # noise standard deviation, for the moment it is absent
y_train = np.random.normal(m * x_train + b, sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(m * x_valid + b, sigma)
# plot training and target dataset

plt.plot(x_valid, y_target)
plt.scatter(x_valid, y_valid, color='r')
plt.grid(True); plt.show()

# %%
# compose the NN model
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

model = tf.keras.Sequential()
model.add(Dense(1, input_shape=(1,)))

# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])

# get a summary of our composed model
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1)                 2
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit the model using training dataset
# over 10 epochs of 32 batch size each
# report training progress against validation data
history = model.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=100,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))

# evaluate model
score = model.evaluate(x_valid, y_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])

# evaluate model with the exact curve
score = model.evaluate(x_valid, y_target, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/100
# 16/16 [==============================] - 0s 7ms/step - loss: 4.7475 - mse: 4.7475 - val_loss: 3.8689 - val_mse: 3.8689
# Epoch 2/100
# 16/16 [==============================] - 0s 3ms/step - loss: 3.6755 - mse: 3.6755 - val_loss: 3.0169 - val_mse: 3.0169
# Epoch 3/100
# 16/16 [==============================] - 0s 4ms/step - loss: 2.8861 - mse: 2.8861 - val_loss: 2.3949 - val_mse: 2.3949
# Epoch 4/100
# 16/16 [==============================] - 0s 3ms/step - loss: 2.3042 - mse: 2.3042 - val_loss: 1.9203 - val_mse: 1.9203
# Epoch 5/100
# 16/16 [==============================] - 0s 3ms/step - loss: 1.8579 - mse: 1.8579 - val_loss: 1.5544 - val_mse: 1.5544
# Epoch 6/100
# 16/16 [==============================] - 0s 3ms/step - loss: 1.5111 - mse: 1.5111 - val_loss: 1.2670 - val_mse: 1.2670
# Epoch 7/100
# 16/16 [==============================] - 0s 3ms/step - loss: 1.2369 - mse: 1.2369 - val_loss: 1.0446 - val_mse: 1.0446
# Epoch 8/100
# 16/16 [==============================] - 0s 3ms/step - loss: 1.0223 - mse: 1.0223 - val_loss: 0.8643 - val_mse: 0.8643
# Epoch 9/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.8490 - mse: 0.8490 - val_loss: 0.7240 - val_mse: 0.7240
# Epoch 10/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.7122 - mse: 0.7122 - val_loss: 0.6125 - val_mse: 0.6125
# Epoch 11/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6029 - mse: 0.6029 - val_loss: 0.5221 - val_mse: 0.5221
# Epoch 12/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5143 - mse: 0.5143 - val_loss: 0.4507 - val_mse: 0.4507
# Epoch 13/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4436 - mse: 0.4436 - val_loss: 0.3947 - val_mse: 0.3947
# Epoch 14/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3873 - mse: 0.3873 - val_loss: 0.3485 - val_mse: 0.3485
# Epoch 15/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3417 - mse: 0.3417 - val_loss: 0.3129 - val_mse: 0.3129
# Epoch 16/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3049 - mse: 0.3049 - val_loss: 0.2842 - val_mse: 0.2842
# Epoch 17/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2759 - mse: 0.2759 - val_loss: 0.2614 - val_mse: 0.2614
# Epoch 18/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2524 - mse: 0.2524 - val_loss: 0.2432 - val_mse: 0.2432
# Epoch 19/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2337 - mse: 0.2337 - val_loss: 0.2290 - val_mse: 0.2290
# Epoch 20/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2186 - mse: 0.2186 - val_loss: 0.2179 - val_mse: 0.2179
# Epoch 21/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2063 - mse: 0.2063 - val_loss: 0.2088 - val_mse: 0.2088
# Epoch 22/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1964 - mse: 0.1964 - val_loss: 0.2020 - val_mse: 0.2020
# Epoch 23/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1887 - mse: 0.1887 - val_loss: 0.1966 - val_mse: 0.1966
# Epoch 24/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1825 - mse: 0.1825 - val_loss: 0.1924 - val_mse: 0.1924
# Epoch 25/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1774 - mse: 0.1774 - val_loss: 0.1887 - val_mse: 0.1887
# Epoch 26/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1734 - mse: 0.1734 - val_loss: 0.1866 - val_mse: 0.1866
# Epoch 27/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1700 - mse: 0.1700 - val_loss: 0.1848 - val_mse: 0.1848
# Epoch 28/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1674 - mse: 0.1674 - val_loss: 0.1828 - val_mse: 0.1828
# Epoch 29/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1653 - mse: 0.1653 - val_loss: 0.1811 - val_mse: 0.1811
# Epoch 30/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1636 - mse: 0.1636 - val_loss: 0.1801 - val_mse: 0.1801
# Epoch 31/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1622 - mse: 0.1622 - val_loss: 0.1792 - val_mse: 0.1792
# Epoch 32/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1611 - mse: 0.1611 - val_loss: 0.1785 - val_mse: 0.1785
# Epoch 33/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1601 - mse: 0.1601 - val_loss: 0.1783 - val_mse: 0.1783
# Epoch 34/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1595 - mse: 0.1595 - val_loss: 0.1776 - val_mse: 0.1776
# Epoch 35/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1589 - mse: 0.1589 - val_loss: 0.1783 - val_mse: 0.1783
# Epoch 36/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1584 - mse: 0.1584 - val_loss: 0.1784 - val_mse: 0.1784
# Epoch 37/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1581 - mse: 0.1581 - val_loss: 0.1782 - val_mse: 0.1782
# Epoch 38/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1577 - mse: 0.1577 - val_loss: 0.1778 - val_mse: 0.1778
# Epoch 39/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1574 - mse: 0.1574 - val_loss: 0.1778 - val_mse: 0.1778
# Epoch 40/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1574 - mse: 0.1574 - val_loss: 0.1775 - val_mse: 0.1775
# Epoch 41/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1572 - mse: 0.1572 - val_loss: 0.1778 - val_mse: 0.1778
# Epoch 42/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1570 - mse: 0.1570 - val_loss: 0.1776 - val_mse: 0.1776
# Epoch 43/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1569 - mse: 0.1569 - val_loss: 0.1779 - val_mse: 0.1779
# Epoch 44/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1569 - mse: 0.1569 - val_loss: 0.1784 - val_mse: 0.1784
# Epoch 45/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1568 - mse: 0.1568 - val_loss: 0.1785 - val_mse: 0.1785
# Epoch 46/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1567 - mse: 0.1567 - val_loss: 0.1786 - val_mse: 0.1786
# Epoch 47/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1567 - mse: 0.1567 - val_loss: 0.1784 - val_mse: 0.1784
# Epoch 48/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1567 - mse: 0.1567 - val_loss: 0.1786 - val_mse: 0.1786
# Epoch 49/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1566 - mse: 0.1566 - val_loss: 0.1786 - val_mse: 0.1786
# Epoch 50/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1566 - mse: 0.1566 - val_loss: 0.1778 - val_mse: 0.1778
# Epoch 51/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1566 - mse: 0.1566 - val_loss: 0.1778 - val_mse: 0.1778
# Epoch 52/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1566 - mse: 0.1566 - val_loss: 0.1782 - val_mse: 0.1782
# Epoch 53/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1566 - mse: 0.1566 - val_loss: 0.1780 - val_mse: 0.1780
# Epoch 54/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1566 - mse: 0.1566 - val_loss: 0.1782 - val_mse: 0.1782
# Epoch 55/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1566 - mse: 0.1566 - val_loss: 0.1781 - val_mse: 0.1781
# Epoch 56/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1565 - mse: 0.1565 - val_loss: 0.1784 - val_mse: 0.1784
# Epoch 57/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1566 - mse: 0.1566 - val_loss: 0.1785 - val_mse: 0.1785
# Epoch 58/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1565 - mse: 0.1565 - val_loss: 0.1783 - val_mse: 0.1783
# Epoch 59/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1566 - mse: 0.1566 - val_loss: 0.1789 - val_mse: 0.1789
# Epoch 60/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1566 - mse: 0.1566 - val_loss: 0.1785 - val_mse: 0.1785
# Epoch 61/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1565 - mse: 0.1565 - val_loss: 0.1783 - val_mse: 0.1783
# Epoch 62/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1566 - mse: 0.1566 - val_loss: 0.1783 - val_mse: 0.1783
# Epoch 63/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1566 - mse: 0.1566 - val_loss: 0.1785 - val_mse: 0.1785
# Epoch 64/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1566 - mse: 0.1566 - val_loss: 0.1783 - val_mse: 0.1783
# Epoch 65/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1566 - mse: 0.1566 - val_loss: 0.1785 - val_mse: 0.1785
# Epoch 66/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1566 - mse: 0.1566 - val_loss: 0.1787 - val_mse: 0.1787
# Epoch 67/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1566 - mse: 0.1566 - val_loss: 0.1790 - val_mse: 0.1790
# Epoch 68/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1566 - mse: 0.1566 - val_loss: 0.1787 - val_mse: 0.1787
# Epoch 69/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1565 - mse: 0.1565 - val_loss: 0.1789 - val_mse: 0.1789
# Epoch 70/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1565 - mse: 0.1565 - val_loss: 0.1791 - val_mse: 0.1791
# Epoch 71/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1565 - mse: 0.1565 - val_loss: 0.1791 - val_mse: 0.1791
# Epoch 72/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1565 - mse: 0.1565 - val_loss: 0.1789 - val_mse: 0.1789
# Epoch 73/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1566 - mse: 0.1566 - val_loss: 0.1791 - val_mse: 0.1791
# Epoch 74/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1565 - mse: 0.1565 - val_loss: 0.1787 - val_mse: 0.1787
# Epoch 75/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1566 - mse: 0.1566 - val_loss: 0.1785 - val_mse: 0.1785
# Epoch 76/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1565 - mse: 0.1565 - val_loss: 0.1787 - val_mse: 0.1787
# Epoch 77/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1565 - mse: 0.1565 - val_loss: 0.1788 - val_mse: 0.1788
# Epoch 78/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1566 - mse: 0.1566 - val_loss: 0.1787 - val_mse: 0.1787
# Epoch 79/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1566 - mse: 0.1566 - val_loss: 0.1790 - val_mse: 0.1790
# Epoch 80/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1566 - mse: 0.1566 - val_loss: 0.1790 - val_mse: 0.1790
# Epoch 81/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1566 - mse: 0.1566 - val_loss: 0.1789 - val_mse: 0.1789
# Epoch 82/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1566 - mse: 0.1566 - val_loss: 0.1788 - val_mse: 0.1788
# Epoch 83/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1566 - mse: 0.1566 - val_loss: 0.1789 - val_mse: 0.1789
# Epoch 84/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1566 - mse: 0.1566 - val_loss: 0.1792 - val_mse: 0.1792
# Epoch 85/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1565 - mse: 0.1565 - val_loss: 0.1790 - val_mse: 0.1790
# Epoch 86/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1566 - mse: 0.1566 - val_loss: 0.1792 - val_mse: 0.1792
# Epoch 87/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1565 - mse: 0.1565 - val_loss: 0.1793 - val_mse: 0.1793
# Epoch 88/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1566 - mse: 0.1566 - val_loss: 0.1795 - val_mse: 0.1795
# Epoch 89/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1566 - mse: 0.1566 - val_loss: 0.1801 - val_mse: 0.1801
# Epoch 90/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1566 - mse: 0.1566 - val_loss: 0.1794 - val_mse: 0.1794
# Epoch 91/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1565 - mse: 0.1565 - val_loss: 0.1795 - val_mse: 0.1795
# Epoch 92/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1565 - mse: 0.1565 - val_loss: 0.1795 - val_mse: 0.1795
# Epoch 93/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1565 - mse: 0.1565 - val_loss: 0.1794 - val_mse: 0.1794
# Epoch 94/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1566 - mse: 0.1566 - val_loss: 0.1795 - val_mse: 0.1795
# Epoch 95/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1566 - mse: 0.1566 - val_loss: 0.1796 - val_mse: 0.1796
# Epoch 96/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1566 - mse: 0.1566 - val_loss: 0.1793 - val_mse: 0.1793
# Epoch 97/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1567 - mse: 0.1567 - val_loss: 0.1788 - val_mse: 0.1788
# Epoch 98/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1566 - mse: 0.1566 - val_loss: 0.1788 - val_mse: 0.1788
# Epoch 99/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1566 - mse: 0.1566 - val_loss: 0.1795 - val_mse: 0.1795
# Epoch 100/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1566 - mse: 0.1566 - val_loss: 0.1796 - val_mse: 0.1796
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1796 - mse: 0.1796
#
# Test loss: 0.17958083748817444
# Test accuracy: 0.17958083748817444
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0029 - mse: 0.0029
#
# Test loss: 0.002906008856371045
# Test accuracy: 0.002906008856371045

# %%
# return weights
print()
print("model weights")
model.get_weights()
# Out:
# model weights
# [array([[2.0434206]], dtype=float32), array([0.954213], dtype=float32)]

# %%
# look into training history
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %%
x_predicted = np.random.uniform(-1, 1, 100)
y_predicted = model.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
plt.grid(True)
plt.show()

# %% [markdown]
# ## **Exercise 11.2**

# %% [markdown]
# In this exercise we try a more difficult fit, because it's non linear, and that means that even our model will be more complicated. The function is $f(x)=4-3x-2x^2+3x^3$ for $x \in [-1,1]$.
#
# I've started adiing layers one to one, increasing the number o neurons, but the fit wasn't working. It started fitting better when I've changed the activation lìfunction of some layers, using the "selu". In the chose of the activation funtion I've excluded the functions with plateau, and then I've tried differend combinations of "selu", "elu" and "softplus". In the last plot I show the different prediction of $3$ models: the one with few layers and "relu" activation function, one with different activation funtions and the final one. I've tried changin optimizer and loss, but I've obtained worst results, so at the end I've came back to the ones I was using in the beginning: the "standard gradient descend" as optimizer and the "mean square error" as loss. Abou the metric I haven't found great changes in my model changing it.
#
# As expected I've checked that incresing the layers and the neurons (so the complexity o fthe model) was increasing the eprecision of my fit. But I've found a problem that even a complex model hasn't fixed: fitting the very end of the function, that has a little growth at the end. Indeed even the final model I've found fitted the end only sometimes (I've found different results rerunning the model).
#
# The results are shown using $\sigma=0$, but I've tried increasing it and it still works. (I've decided to not show all the results to avoid having a juyter that was unreadable and too long).
#
# As conclusion I want to say that the fit works well in the range $[-1,1]$, but fails when I pass points out fron this range. I've tried plotting some points and, as you can see from the last plot, the prediction of the model is wrong, because the model is not trained outside this range.

# %%
import numpy as np
import matplotlib.pyplot as plt
# target parameters of f(x) = a*x^3+b*x^2+c*x+d
a=3
b=-2
c=-3
d=4

# generate training inputs
np.random.seed(0)
x_train = np.random.uniform(-1, 1, 3000)
x_valid = np.random.uniform(-1, 1, 300)
x_valid.sort()
y_target = a*pow(x_valid,3)+b*pow(x_valid,2)+c*x_valid+d  # ideal (target) linear function

sigma = 0.0 # noise standard deviation, for the moment it is absent
y_train = np.random.normal(a*pow(x_train,3)+b*pow(x_train,2)+c*x_train+d, sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(a*pow(x_valid,3)+b*pow(x_valid,2)+c*x_valid+d, sigma)
# plot training and target dataset

plt.plot(x_valid, y_target)
plt.scatter(x_valid, y_valid, color='r')
plt.grid(True); plt.show()

# %%
# compose the NN model
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects
from keras import optimizers, losses, metrics

model = tf.keras.Sequential()
model.add(Dense(30, input_shape=(1,), activation="selu"))
model.add(Dense(30, activation="softplus"))
model.add(Dense(20, activation="selu"))
model.add(Dense(20, activation="elu"))
model.add(Dense(1, activation="elu"))

# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='sgd', loss='mse', metrics=["mae"])

model.summary()
# Out:
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_91 (Dense)             (None, 30)                60
# _________________________________________________________________
# dense_92 (Dense)             (None, 30)                930
# _________________________________________________________________
# dense_93 (Dense)             (None, 20)                620
# _________________________________________________________________
# dense_94 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_95 (Dense)             (None, 1)                 21
# =================================================================
# Total params: 2,051
# Trainable params: 2,051
# Non-trainable params: 0
# _________________________________________________________________

# %%
#fit the model using training dataset
history = model.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=150,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))

# evaluate model
score = model.evaluate(x_valid, y_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])

# evaluate model with the exact curve
score = model.evaluate(x_valid, y_target, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])

# %%
# look into training history
# Plot training & validation loss values

model.get_weights()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %% [markdown]
# old models used just for the comparison graph

# %%
model1 = tf.keras.Sequential()
model1.add(Dense(30, input_shape=(1,)))
model1.add(Dense(30))
model1.add(Dense(20))
model1.add(Dense(1))

# compile the model choosing optimizer, loss and metrics objects
model1.compile(optimizer='sgd', loss='mse', metrics=["mae"])
#fit the model using training dataset
history = model1.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=150,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))

# evaluate model
score = model1.evaluate(x_valid, y_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])

# %%
model2 = tf.keras.Sequential()
model2.add(Dense(30, input_shape=(1,), activation="selu"))
model2.add(Dense(30, activation="softplus"))
model2.add(Dense(20, activation="selu"))
model2.add(Dense(20, activation="elu"))
model2.add(Dense(1, activation="elu"))

# compile the model choosing optimizer, loss and metrics objects
model2.compile(optimizer='Adagrad', loss='mse', metrics=["mae"])
#fit the model using training dataset
history = model2.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=150,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))

# evaluate model
score = model2.evaluate(x_valid, y_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])

# %% [markdown]
# - compariosn between differend NNs

# %%
x_predicted = np.random.uniform(-1, 1, 100)
y_predicted = model.predict(x_predicted)
y1_predicted=model1.predict(x_predicted)
y2_predicted=model2.predict(x_predicted)
plt.scatter(x_predicted, y_predicted, color='r')
plt.scatter(x_predicted, y1_predicted, color='g')
plt.scatter(x_predicted, y2_predicted, color='b')
plt.plot(x_valid, y_target)
plt.grid(True)
plt.show()

# %% [markdown]
# - plot outside the trained region

# %%
x_predicted = np.random.uniform(-1.3, 1.3, 200)
y_predicted = model.predict(x_predicted)
plt.scatter(x_predicted, y_predicted, color='r')
x_predicted.sort()
y_target = a*pow(x_predicted,3)+b*pow(x_predicted,2)+c*x_predicted+d
plt.plot(x_predicted, y_target)
plt.grid(True)
plt.show()

# %% [markdown]
# ## **Exercise 11.3**

# %% [markdown]
# For this exercise the work was incredibly easy, because I've tried using the same model that I've built for the prevois exercise and it worked perfectly. Now the function to fit is the 2D function $f(x,y) = \sin(x^2+y^2)$ in the range $x \in [-3/2,3/2]$ and $y \in [-3/2,3/2]$.
# Because of the increased complexity I've used a larger $N_{\mathrm{train}}$, but i's teh only thing I needed to change to make it work.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits import mplot3d
# %matplotlib inline
#f(x,y) = sin(x^2+y^2)
def f(x, y):
    return np.sin(x ** 2 + y ** 2)

# generate training inputs
np.random.seed(0)
n_tr = 5000
n_val = 500
x_tr = np.zeros((n_tr, 2))
y_tr = np.zeros(n_tr)
x_val = np.zeros((n_val, 2))
y_val = np.zeros(n_val)
x=np.zeros(n_val)
y=np.zeros(n_val)
#y_target=np.zeros(n_val)
sigma = 0.0 # noise standard deviation

for i in range(n_tr):
  x_tr[i,0]=np.random.uniform(-1.5, 1.5)
  x_tr[i,1]=np.random.uniform(-1.5, 1.5)
  y_tr[i]=np.random.normal(np.sin(pow(x_tr[i,0],2)+pow(x_tr[i,1],2)), sigma)

for i in range(n_val):
  x_val[i,0]=np.random.uniform(-1.5, 1.5)
  x_val[i,1]=np.random.uniform(-1.5, 1.5)
  x[i]=x_val[i,0]
  y[i]=x_val[i,1]
  y_val[i]=np.random.normal(np.sin(pow(x[i],2)+pow(y[i],2)), sigma)
 # y_target[i]=np.sin(pow(x_tr[i,0],2)+pow(x_tr[i,1],2))
y_target=f(x,y)
fig = plt.figure(figsize=(15,10))
ax = plt.axes(projection="3d")  

ax.plot_trisurf(x, y, y_target,cmap="viridis",edgecolor="none")
ax.scatter3D(x,y, y_val, color='r')
plt.grid(True); plt.show()

# %%
# compose the NN model
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects
from keras import optimizers, losses, metrics

model = tf.keras.Sequential()
model.add(Dense(30, input_shape=(2,), activation="selu"))
model.add(Dense(30, activation="softplus"))
model.add(Dense(20, activation="selu"))
model.add(Dense(20, activation="selu"))
model.add(Dense(20, activation="elu"))
model.add(Dense(1, activation="elu"))

# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='sgd', loss='mse', metrics=["mae"])

model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_20 (Dense)             (None, 30)                90
# _________________________________________________________________
# dense_21 (Dense)             (None, 30)                930
# _________________________________________________________________
# dense_22 (Dense)             (None, 20)                620
# _________________________________________________________________
# dense_23 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_24 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_25 (Dense)             (None, 1)                 21
# =================================================================
# Total params: 2,501
# Trainable params: 2,501
# Non-trainable params: 0
# _________________________________________________________________

# %%
#fit the model using training dataset
history = model.fit(x=x_tr, y=y_tr, 
          batch_size=32, epochs=200,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_val, y_val))
# Out:
# Epoch 1/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1632 - mae: 0.3206 - val_loss: 0.1472 - val_mae: 0.3176
# Epoch 2/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1506 - mae: 0.3102 - val_loss: 0.1559 - val_mae: 0.3423
# Epoch 3/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1499 - mae: 0.3090 - val_loss: 0.1445 - val_mae: 0.3206
# Epoch 4/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1478 - mae: 0.3067 - val_loss: 0.1435 - val_mae: 0.3077
# Epoch 5/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1482 - mae: 0.3086 - val_loss: 0.1848 - val_mae: 0.3086
# Epoch 6/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1472 - mae: 0.3076 - val_loss: 0.1436 - val_mae: 0.3022
# Epoch 7/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1422 - mae: 0.3025 - val_loss: 0.1433 - val_mae: 0.3251
# Epoch 8/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1423 - mae: 0.3019 - val_loss: 0.1374 - val_mae: 0.3019
# Epoch 9/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1386 - mae: 0.2980 - val_loss: 0.1354 - val_mae: 0.3011
# Epoch 10/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1392 - mae: 0.2996 - val_loss: 0.1824 - val_mae: 0.3773
# Epoch 11/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1382 - mae: 0.2977 - val_loss: 0.1352 - val_mae: 0.3130
# Epoch 12/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1363 - mae: 0.2960 - val_loss: 0.1794 - val_mae: 0.3020
# Epoch 13/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1335 - mae: 0.2916 - val_loss: 0.1305 - val_mae: 0.3101
# Epoch 14/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1311 - mae: 0.2903 - val_loss: 0.1280 - val_mae: 0.2819
# Epoch 15/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1265 - mae: 0.2847 - val_loss: 0.1410 - val_mae: 0.2776
# Epoch 16/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1226 - mae: 0.2780 - val_loss: 0.1988 - val_mae: 0.3910
# Epoch 17/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1194 - mae: 0.2744 - val_loss: 0.1080 - val_mae: 0.2567
# Epoch 18/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1174 - mae: 0.2713 - val_loss: 0.0990 - val_mae: 0.2635
# Epoch 19/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1123 - mae: 0.2632 - val_loss: 0.0928 - val_mae: 0.2534
# Epoch 20/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1096 - mae: 0.2592 - val_loss: 0.2373 - val_mae: 0.3888
# Epoch 21/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1083 - mae: 0.2594 - val_loss: 0.0905 - val_mae: 0.2441
# Epoch 22/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1026 - mae: 0.2498 - val_loss: 0.0882 - val_mae: 0.2486
# Epoch 23/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1032 - mae: 0.2511 - val_loss: 0.0886 - val_mae: 0.2239
# Epoch 24/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0960 - mae: 0.2415 - val_loss: 0.1063 - val_mae: 0.2782
# Epoch 25/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1012 - mae: 0.2480 - val_loss: 0.0836 - val_mae: 0.2433
# Epoch 26/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0925 - mae: 0.2356 - val_loss: 0.1146 - val_mae: 0.2875
# Epoch 27/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0920 - mae: 0.2335 - val_loss: 0.0743 - val_mae: 0.2274
# Epoch 28/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0855 - mae: 0.2255 - val_loss: 0.0702 - val_mae: 0.2157
# Epoch 29/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0870 - mae: 0.2270 - val_loss: 0.0718 - val_mae: 0.2157
# Epoch 30/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0788 - mae: 0.2151 - val_loss: 0.0640 - val_mae: 0.1903
# Epoch 31/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0816 - mae: 0.2194 - val_loss: 0.0595 - val_mae: 0.1946
# Epoch 32/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0782 - mae: 0.2150 - val_loss: 0.0573 - val_mae: 0.1872
# Epoch 33/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0881 - mae: 0.2288 - val_loss: 0.0647 - val_mae: 0.2008
# Epoch 34/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0724 - mae: 0.2054 - val_loss: 0.0807 - val_mae: 0.2158
# Epoch 35/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0753 - mae: 0.2100 - val_loss: 0.1722 - val_mae: 0.3548
# Epoch 36/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0775 - mae: 0.2127 - val_loss: 0.0826 - val_mae: 0.2381
# Epoch 37/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0732 - mae: 0.2076 - val_loss: 0.1505 - val_mae: 0.3328
# Epoch 38/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0708 - mae: 0.2046 - val_loss: 0.0745 - val_mae: 0.2072
# Epoch 39/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0685 - mae: 0.1964 - val_loss: 0.1371 - val_mae: 0.3110
# Epoch 40/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0660 - mae: 0.1962 - val_loss: 0.0681 - val_mae: 0.2058
# Epoch 41/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0634 - mae: 0.1924 - val_loss: 0.0885 - val_mae: 0.2451
# Epoch 42/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0678 - mae: 0.1983 - val_loss: 0.0594 - val_mae: 0.1845
# Epoch 43/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0597 - mae: 0.1869 - val_loss: 0.0961 - val_mae: 0.2538
# Epoch 44/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0607 - mae: 0.1885 - val_loss: 0.0382 - val_mae: 0.1467
# Epoch 45/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0567 - mae: 0.1826 - val_loss: 0.0497 - val_mae: 0.1736
# Epoch 46/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0593 - mae: 0.1840 - val_loss: 0.0503 - val_mae: 0.1748
# Epoch 47/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0546 - mae: 0.1784 - val_loss: 0.0324 - val_mae: 0.1361
# Epoch 48/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0593 - mae: 0.1857 - val_loss: 0.0348 - val_mae: 0.1387
# Epoch 49/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0471 - mae: 0.1625 - val_loss: 0.0591 - val_mae: 0.1917
# Epoch 50/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0488 - mae: 0.1700 - val_loss: 0.0483 - val_mae: 0.1735
# Epoch 51/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0603 - mae: 0.1841 - val_loss: 0.0390 - val_mae: 0.1509
# Epoch 52/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0410 - mae: 0.1539 - val_loss: 0.0307 - val_mae: 0.1352
# Epoch 53/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0457 - mae: 0.1645 - val_loss: 0.2090 - val_mae: 0.4204
# Epoch 54/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0541 - mae: 0.1750 - val_loss: 0.0837 - val_mae: 0.2483
# Epoch 55/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0372 - mae: 0.1450 - val_loss: 0.0392 - val_mae: 0.1594
# Epoch 56/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0472 - mae: 0.1662 - val_loss: 0.0274 - val_mae: 0.1222
# Epoch 57/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0398 - mae: 0.1526 - val_loss: 0.0383 - val_mae: 0.1569
# Epoch 58/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0408 - mae: 0.1541 - val_loss: 0.0212 - val_mae: 0.1075
# Epoch 59/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0380 - mae: 0.1510 - val_loss: 0.0322 - val_mae: 0.1416
# Epoch 60/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0338 - mae: 0.1412 - val_loss: 0.0422 - val_mae: 0.1694
# Epoch 61/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0413 - mae: 0.1527 - val_loss: 0.0194 - val_mae: 0.1015
# Epoch 62/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0336 - mae: 0.1390 - val_loss: 0.0353 - val_mae: 0.1537
# Epoch 63/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0370 - mae: 0.1488 - val_loss: 0.0446 - val_mae: 0.1675
# Epoch 64/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0298 - mae: 0.1305 - val_loss: 0.0181 - val_mae: 0.1002
# Epoch 65/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0309 - mae: 0.1335 - val_loss: 0.0534 - val_mae: 0.1995
# Epoch 66/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0334 - mae: 0.1399 - val_loss: 0.0183 - val_mae: 0.1028
# Epoch 67/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0294 - mae: 0.1319 - val_loss: 0.0218 - val_mae: 0.1090
# Epoch 68/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0310 - mae: 0.1297 - val_loss: 0.0662 - val_mae: 0.2216
# Epoch 69/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0253 - mae: 0.1230 - val_loss: 0.0187 - val_mae: 0.1062
# Epoch 70/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0300 - mae: 0.1303 - val_loss: 0.0179 - val_mae: 0.1027
# Epoch 71/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0235 - mae: 0.1161 - val_loss: 0.0143 - val_mae: 0.0870
# Epoch 72/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0256 - mae: 0.1227 - val_loss: 0.0250 - val_mae: 0.1265
# Epoch 73/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0230 - mae: 0.1125 - val_loss: 0.0208 - val_mae: 0.1096
# Epoch 74/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0258 - mae: 0.1220 - val_loss: 0.0135 - val_mae: 0.0864
# Epoch 75/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0202 - mae: 0.1091 - val_loss: 0.0166 - val_mae: 0.1036
# Epoch 76/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0286 - mae: 0.1279 - val_loss: 0.0328 - val_mae: 0.1355
# Epoch 77/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0203 - mae: 0.1067 - val_loss: 0.1137 - val_mae: 0.2999
# Epoch 78/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0166 - mae: 0.0964 - val_loss: 0.0711 - val_mae: 0.2333
# Epoch 79/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0232 - mae: 0.1182 - val_loss: 0.0237 - val_mae: 0.1178
# Epoch 80/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0195 - mae: 0.1101 - val_loss: 0.0101 - val_mae: 0.0741
# Epoch 81/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0218 - mae: 0.1141 - val_loss: 0.0114 - val_mae: 0.0774
# Epoch 82/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0184 - mae: 0.1038 - val_loss: 0.0117 - val_mae: 0.0786
# Epoch 83/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0198 - mae: 0.1098 - val_loss: 0.0254 - val_mae: 0.1347
# Epoch 84/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0175 - mae: 0.0987 - val_loss: 0.0251 - val_mae: 0.1324
# Epoch 85/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0181 - mae: 0.1020 - val_loss: 0.0145 - val_mae: 0.0914
# Epoch 86/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0157 - mae: 0.0962 - val_loss: 0.0105 - val_mae: 0.0728
# Epoch 87/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0164 - mae: 0.0957 - val_loss: 0.0239 - val_mae: 0.1192
# Epoch 88/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0156 - mae: 0.0966 - val_loss: 0.0105 - val_mae: 0.0774
# Epoch 89/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0170 - mae: 0.0942 - val_loss: 0.0398 - val_mae: 0.1710
# Epoch 90/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0135 - mae: 0.0886 - val_loss: 0.0506 - val_mae: 0.1925
# Epoch 91/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0139 - mae: 0.0901 - val_loss: 0.0089 - val_mae: 0.0701
# Epoch 92/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0129 - mae: 0.0869 - val_loss: 0.0102 - val_mae: 0.0804
# Epoch 93/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0121 - mae: 0.0845 - val_loss: 0.0158 - val_mae: 0.1041
# Epoch 94/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0132 - mae: 0.0875 - val_loss: 0.0103 - val_mae: 0.0762
# Epoch 95/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0104 - mae: 0.0782 - val_loss: 0.0486 - val_mae: 0.1988
# Epoch 96/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0127 - mae: 0.0848 - val_loss: 0.0071 - val_mae: 0.0639
# Epoch 97/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0131 - mae: 0.0888 - val_loss: 0.0183 - val_mae: 0.1008
# Epoch 98/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0091 - mae: 0.0720 - val_loss: 0.0083 - val_mae: 0.0771
# Epoch 99/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0109 - mae: 0.0768 - val_loss: 0.0079 - val_mae: 0.0614
# Epoch 100/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0076 - mae: 0.0649 - val_loss: 0.0097 - val_mae: 0.0784
# Epoch 101/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0119 - mae: 0.0819 - val_loss: 0.0085 - val_mae: 0.0698
# Epoch 102/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0082 - mae: 0.0682 - val_loss: 0.0053 - val_mae: 0.0569
# Epoch 103/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0081 - mae: 0.0681 - val_loss: 0.0045 - val_mae: 0.0490
# Epoch 104/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0096 - mae: 0.0737 - val_loss: 0.0044 - val_mae: 0.0516
# Epoch 105/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0090 - mae: 0.0737 - val_loss: 0.0127 - val_mae: 0.0906
# Epoch 106/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0067 - mae: 0.0620 - val_loss: 0.0062 - val_mae: 0.0638
# Epoch 107/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0104 - mae: 0.0777 - val_loss: 0.0070 - val_mae: 0.0594
# Epoch 108/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0061 - mae: 0.0582 - val_loss: 0.0044 - val_mae: 0.0515
# Epoch 109/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0098 - mae: 0.0786 - val_loss: 0.0057 - val_mae: 0.0614
# Epoch 110/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0107 - mae: 0.0766 - val_loss: 0.0091 - val_mae: 0.0723
# Epoch 111/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0076 - mae: 0.0672 - val_loss: 0.0042 - val_mae: 0.0469
# Epoch 112/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0086 - mae: 0.0684 - val_loss: 0.0197 - val_mae: 0.1229
# Epoch 113/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0068 - mae: 0.0609 - val_loss: 0.0033 - val_mae: 0.0425
# Epoch 114/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0076 - mae: 0.0660 - val_loss: 0.0054 - val_mae: 0.0547
# Epoch 115/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0071 - mae: 0.0646 - val_loss: 0.0036 - val_mae: 0.0436
# Epoch 116/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0064 - mae: 0.0609 - val_loss: 0.0032 - val_mae: 0.0445
# Epoch 117/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0067 - mae: 0.0610 - val_loss: 0.0065 - val_mae: 0.0671
# Epoch 118/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0058 - mae: 0.0584 - val_loss: 0.0054 - val_mae: 0.0589
# Epoch 119/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0055 - mae: 0.0571 - val_loss: 0.0027 - val_mae: 0.0404
# Epoch 120/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0086 - mae: 0.0686 - val_loss: 0.0060 - val_mae: 0.0637
# Epoch 121/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0073 - mae: 0.0649 - val_loss: 0.0161 - val_mae: 0.1148
# Epoch 122/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0054 - mae: 0.0551 - val_loss: 0.0028 - val_mae: 0.0399
# Epoch 123/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0050 - mae: 0.0529 - val_loss: 0.0030 - val_mae: 0.0432
# Epoch 124/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0056 - mae: 0.0563 - val_loss: 0.0026 - val_mae: 0.0386
# Epoch 125/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0052 - mae: 0.0542 - val_loss: 0.0028 - val_mae: 0.0402
# Epoch 126/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0062 - mae: 0.0591 - val_loss: 0.0061 - val_mae: 0.0646
# Epoch 127/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0047 - mae: 0.0522 - val_loss: 0.0065 - val_mae: 0.0669
# Epoch 128/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0073 - mae: 0.0672 - val_loss: 0.0302 - val_mae: 0.1592
# Epoch 129/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0069 - mae: 0.0618 - val_loss: 0.0051 - val_mae: 0.0589
# Epoch 130/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0034 - mae: 0.0439 - val_loss: 0.0023 - val_mae: 0.0366
# Epoch 131/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0046 - mae: 0.0509 - val_loss: 0.0030 - val_mae: 0.0455
# Epoch 132/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0039 - mae: 0.0474 - val_loss: 0.0021 - val_mae: 0.0353
# Epoch 133/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0058 - mae: 0.0569 - val_loss: 0.0032 - val_mae: 0.0418
# Epoch 134/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0039 - mae: 0.0478 - val_loss: 0.0022 - val_mae: 0.0371
# Epoch 135/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0052 - mae: 0.0558 - val_loss: 0.0247 - val_mae: 0.1455
# Epoch 136/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0054 - mae: 0.0550 - val_loss: 0.0038 - val_mae: 0.0487
# Epoch 137/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0058 - mae: 0.0567 - val_loss: 0.0028 - val_mae: 0.0407
# Epoch 138/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0076 - mae: 0.0623 - val_loss: 0.0038 - val_mae: 0.0441
# Epoch 139/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0039 - mae: 0.0479 - val_loss: 0.0054 - val_mae: 0.0561
# Epoch 140/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0053 - mae: 0.0524 - val_loss: 0.0022 - val_mae: 0.0373
# Epoch 141/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0028 - mae: 0.0394 - val_loss: 0.0039 - val_mae: 0.0504
# Epoch 142/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0045 - mae: 0.0506 - val_loss: 0.0037 - val_mae: 0.0434
# Epoch 143/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0029 - mae: 0.0412 - val_loss: 0.0025 - val_mae: 0.0364
# Epoch 144/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0043 - mae: 0.0511 - val_loss: 0.0023 - val_mae: 0.0362
# Epoch 145/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0039 - mae: 0.0470 - val_loss: 0.0126 - val_mae: 0.1008
# Epoch 146/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0045 - mae: 0.0485 - val_loss: 0.0025 - val_mae: 0.0416
# Epoch 147/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0031 - mae: 0.0423 - val_loss: 0.0088 - val_mae: 0.0836
# Epoch 148/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0032 - mae: 0.0426 - val_loss: 0.0060 - val_mae: 0.0667
# Epoch 149/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0051 - mae: 0.0531 - val_loss: 0.0042 - val_mae: 0.0516
# Epoch 150/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0029 - mae: 0.0404 - val_loss: 0.0018 - val_mae: 0.0339
# Epoch 151/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0046 - mae: 0.0507 - val_loss: 0.0090 - val_mae: 0.0742
# Epoch 152/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0028 - mae: 0.0395 - val_loss: 0.0088 - val_mae: 0.0806
# Epoch 153/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0028 - mae: 0.0403 - val_loss: 0.0058 - val_mae: 0.0625
# Epoch 154/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0026 - mae: 0.0384 - val_loss: 0.0051 - val_mae: 0.0611
# Epoch 155/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0032 - mae: 0.0429 - val_loss: 0.0036 - val_mae: 0.0510
# Epoch 156/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0033 - mae: 0.0435 - val_loss: 0.0015 - val_mae: 0.0296
# Epoch 157/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0027 - mae: 0.0394 - val_loss: 0.0014 - val_mae: 0.0285
# Epoch 158/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0066 - mae: 0.0588 - val_loss: 0.0057 - val_mae: 0.0635
# Epoch 159/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0029 - mae: 0.0408 - val_loss: 0.0015 - val_mae: 0.0297
# Epoch 160/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0022 - mae: 0.0342 - val_loss: 0.0037 - val_mae: 0.0475
# Epoch 161/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0029 - mae: 0.0398 - val_loss: 0.0040 - val_mae: 0.0542
# Epoch 162/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0038 - mae: 0.0464 - val_loss: 0.0030 - val_mae: 0.0420
# Epoch 163/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0032 - mae: 0.0415 - val_loss: 0.0014 - val_mae: 0.0295
# Epoch 164/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0042 - mae: 0.0423 - val_loss: 0.0025 - val_mae: 0.0391
# Epoch 165/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0024 - mae: 0.0361 - val_loss: 0.0021 - val_mae: 0.0372
# Epoch 166/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0027 - mae: 0.0375 - val_loss: 0.0020 - val_mae: 0.0333
# Epoch 167/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0025 - mae: 0.0376 - val_loss: 0.0015 - val_mae: 0.0293
# Epoch 168/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0029 - mae: 0.0408 - val_loss: 0.0013 - val_mae: 0.0263
# Epoch 169/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0021 - mae: 0.0349 - val_loss: 0.0028 - val_mae: 0.0417
# Epoch 170/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0026 - mae: 0.0377 - val_loss: 0.0016 - val_mae: 0.0292
# Epoch 171/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0023 - mae: 0.0353 - val_loss: 0.0011 - val_mae: 0.0247
# Epoch 172/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0028 - mae: 0.0401 - val_loss: 0.0066 - val_mae: 0.0692
# Epoch 173/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0024 - mae: 0.0362 - val_loss: 0.0012 - val_mae: 0.0279
# Epoch 174/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0033 - mae: 0.0410 - val_loss: 0.0011 - val_mae: 0.0243
# Epoch 175/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0023 - mae: 0.0361 - val_loss: 0.0013 - val_mae: 0.0265
# Epoch 176/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0029 - mae: 0.0410 - val_loss: 0.0028 - val_mae: 0.0390
# Epoch 177/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0018 - mae: 0.0313 - val_loss: 0.0011 - val_mae: 0.0266
# Epoch 178/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0027 - mae: 0.0386 - val_loss: 9.9489e-04 - val_mae: 0.0243
# Epoch 179/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0017 - mae: 0.0303 - val_loss: 0.0023 - val_mae: 0.0374
# Epoch 180/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0019 - mae: 0.0331 - val_loss: 0.0018 - val_mae: 0.0327
# Epoch 181/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0021 - mae: 0.0339 - val_loss: 0.0020 - val_mae: 0.0354
# Epoch 182/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0029 - mae: 0.0408 - val_loss: 0.0036 - val_mae: 0.0514
# Epoch 183/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0031 - mae: 0.0422 - val_loss: 9.6782e-04 - val_mae: 0.0233
# Epoch 184/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0022 - mae: 0.0334 - val_loss: 0.0011 - val_mae: 0.0259
# Epoch 185/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0018 - mae: 0.0318 - val_loss: 0.0011 - val_mae: 0.0246
# Epoch 186/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0024 - mae: 0.0353 - val_loss: 0.0011 - val_mae: 0.0255
# Epoch 187/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0018 - mae: 0.0320 - val_loss: 0.0021 - val_mae: 0.0328
# Epoch 188/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0023 - mae: 0.0367 - val_loss: 0.0015 - val_mae: 0.0291
# Epoch 189/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0035 - mae: 0.0406 - val_loss: 0.0027 - val_mae: 0.0437
# Epoch 190/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0016 - mae: 0.0302 - val_loss: 0.0031 - val_mae: 0.0451
# Epoch 191/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0021 - mae: 0.0349 - val_loss: 0.0014 - val_mae: 0.0306
# Epoch 192/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0017 - mae: 0.0305 - val_loss: 0.0029 - val_mae: 0.0420
# Epoch 193/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0014 - mae: 0.0278 - val_loss: 0.0276 - val_mae: 0.1343
# Epoch 194/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0026 - mae: 0.0342 - val_loss: 0.0018 - val_mae: 0.0318
# Epoch 195/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0026 - mae: 0.0382 - val_loss: 8.3213e-04 - val_mae: 0.0215
# Epoch 196/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0018 - mae: 0.0312 - val_loss: 0.0011 - val_mae: 0.0236
# Epoch 197/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0014 - mae: 0.0278 - val_loss: 0.0011 - val_mae: 0.0249
# Epoch 198/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0025 - mae: 0.0376 - val_loss: 0.0094 - val_mae: 0.0846
# Epoch 199/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0019 - mae: 0.0320 - val_loss: 0.0039 - val_mae: 0.0556
# Epoch 200/200
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0019 - mae: 0.0327 - val_loss: 9.2464e-04 - val_mae: 0.0230

# %%
# evaluate model
score = model.evaluate(x_val, y_val, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])

# Plot training & validation loss values
model.get_weights()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()
# Out:
# 16/16 [==============================] - 0s 1ms/step - loss: 9.2464e-04 - mae: 0.0230
#
# Test loss: 0.0009246393456123769
# Test accuracy: 0.023012354969978333

# %%
n=500
x0=np.zeros(n)
y0=np.zeros(n)
x_predicted = np.zeros((n, 2))
for i in range(n):
  x_predicted[i,0]=np.random.uniform(-1.5, 1.5)
  x_predicted[i,1]=np.random.uniform(-1.5, 1.5)
  x0[i]=x_predicted[i,0]
  y0[i]=x_predicted[i,1]
y_predicted = model.predict(x_predicted) 

fig = plt.figure(figsize=(15,10))
ax = plt.axes(projection="3d") 
ax.plot_trisurf(x, y, y_target,cmap="viridis",edgecolor="none", alpha=0.2)
#ax.plot_trisurf(x0, y0, y_predicted, cmap="viridis",edgecolor="none")
ax.scatter3D(x0,y0, y_predicted, color='r')
plt.grid(True)
plt.show()
